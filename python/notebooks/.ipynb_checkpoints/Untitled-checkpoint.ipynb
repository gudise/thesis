# %%
from fpga.oscmatrix import *

# %%
help('fpga.oscmatrix')
# Out:
# Help on module fpga.oscmatrix in fpga:
#
# NAME
#     fpga.oscmatrix
#
# DESCRIPTION
#     Este módulo contiene una serie de clases y funciones para implementar en FPGA y medir una matriz de osciladores de
#     anillo, tanto estándar como de Galois.
#
# CLASSES
#     builtins.object
#         GAROMATRIX
#         OSC_SUBMATRIX
#         ROMATRIX
#
#     class GAROMATRIX(builtins.object)
#      |  GAROMATRIX(N_inv=3, submatrices=<fpga.oscmatrix.OSC_SUBMATRIX object at 0x7fd7f8143610>)
#      |
#      |  Objeto que contiene una matriz de osciladores de anillo de Galois.
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, N_inv=3, submatrices=<fpga.oscmatrix.OSC_SUBMATRIX object at 0x7fd7f8143610>)
#      |      Esta función inicializa un objeto 'GAROMATRIX'; se llama automáticamente al crear un nuevo objeto de esta clase.
#      |
#      |      PARÁMETROS:
#      |      -----------
#      |
#      |          N_inv 3
#      |
# ...

# %%
sub_matriz = OSC_SUBMATRIX(N_osc=1)
oscilador = ROMATRIX(3, sub_matriz)

# %%
oscilador.implement(linux=True, board ='zybo', projdir='/home/gds/Escritorio/WDIR/borrar')
# Out:
# N_osc = 1
# N_pdl = 1
#
# (0) <---sel_ro(0)---><---sel_pdl(0)---><---sel_resol(5)---> (4)
#
# fpga part: xc7z010clg400-1
#
# sdk source files: /home/gds/Dropbox/COMPUTACION/REPOS_WRAPPER/repos/fpga/python/notebooks/sdk_src/
